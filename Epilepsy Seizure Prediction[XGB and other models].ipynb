# %% [markdown]
# # IMPORTING MODULES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
epidf = pd.read_csv('/content/Epileptic Seizure Recognition.csv')

# %%
epidf.head()
# Out:
#       Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
epidf.shape
# Out:
# (11500, 180)

# %%
epidf.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# ...

# %%
epidf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 180 entries, Unnamed to y
# dtypes: int64(179), object(1)
# memory usage: 15.8+ MB

# %% [markdown]
# # Data Preprocessing

# %%
epidf.isnull().sum()
# Out:
# Unnamed    0
# X1         0
# X2         0
# X3         0
# X4         0
#           ..
# X175       0
# X176       0
# X177       0
# X178       0
# y          0
# Length: 180, dtype: int64

# %%
epidf['target']=epidf['y']
epidf['target'] = np.where(epidf['target'] == 1, 1, 0)

# %%
epidf['target']
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 11495    0
# 11496    1
# 11497    0
# 11498    0
# 11499    0
# Name: target, Length: 11500, dtype: int64

# %%
X=epidf.drop(columns=['y','target','Unnamed'])
Y=epidf['target']

# %% [markdown]
# # DATA VISUALIZATION

# %%
sns.countplot(data=epidf, x="target")
print(epidf['target'].value_counts())
# Out:
# 0    9200
# 1    2300
# Name: target, dtype: int64

# %% [markdown]
# # TRAINING AND EVALUATING THE MODEL

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit_transform(X_train)
scaler.transform(X_test)
# Out:
# array([[-0.20660926, -0.46045554, -0.74369867, ...,  0.48945241,
#          0.32328443,  0.8686178 ],
#        [ 0.13272881,  0.12802568,  0.13193131, ..., -0.04338236,
#         -0.03117823, -0.01375055],
#        [-0.33758185, -0.41290151, -0.4417573 , ...,  0.21997275,
#          0.22550163,  0.19777611],
#        ...,
#        [ 0.14463541,  0.16369121,  0.19231959, ...,  0.62419223,
#          0.65330139,  0.65104752],
#        [ 0.50778668,  0.56790053,  0.61503751, ...,  0.17097645,
#          0.08493885, -0.05001226],
#        [ 0.02556942,  0.08047164,  0.06550421, ...,  0.17097645,
#          0.13383025,  0.13733992]])

# %%
models=[LogisticRegression( max_iter=3000),SVC()]
for model in models:
  model.fit(X_train,Y_train)
  X_train_pred=model.predict(X_train)
  Accu_train=accuracy_score(X_train_pred,Y_train)
  print(Accu_train)
  X_test_pred=model.predict(X_test)
  Accu_test=accuracy_score(X_test_pred,Y_test)
  print(Accu_test)
# Out:
# 0.8318478260869565
# 0.8178260869565217
# 0.9831521739130434
# 0.97

# %%
xgb_cl = xgb.XGBClassifier()
xgb_cl.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# I am not doing this because the model is already giving great accuracy wihtout any tuning.
#
# *(jk its cos its taking hella lotta time on my crappy pc ╥﹏╥ )*

# %%
#from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
#parameters = {"subsample":[0.5, 0.75, 1],
#"colsample_bytree":[0.5, 0.75, 1],
#"max_depth":[2, 6, 12],
#"min_child_weight":[1,5,15],
#"learning_rate":[0.3, 0.1, 0.03],
#"n_estimators":[100]}

# %%
#classifier=GridSearchCV(xgb_cl,parameters,cv=5)
#classifier.fit(X,Y)

# %% [markdown]
# XGBoost Accuracy

# %%
X_train_pred=xgb_cl.predict(X_train)
Accu_train=accuracy_score(X_train_pred,Y_train)
print(Accu_train)
X_test_pred=xgb_cl.predict(X_test)
Accu_test=accuracy_score(X_test_pred,Y_test)
print(Accu_test)
# Out:
# 1.0
# 0.9665217391304348

# %% [markdown]
# RandomForest Accuracy

# %%
for_cl = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=3)
for_cl.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=3)

# %%
X_train_pred=for_cl.predict(X_train)
Accu_train=accuracy_score(X_train_pred,Y_train)
print(Accu_train)
X_test_pred=for_cl.predict(X_test)
Accu_test=accuracy_score(X_test_pred,Y_test)
print(Accu_test)
# Out:
# 0.9825
# 0.9521739130434783

# %% [markdown]
# We can observe XGBoost is giving us the best accuracy

# %%
#Making a prediction system for XGB

l=[-225,-248,-260,-261,-256,-245,-232,-227,-232,-249,-270,-293,-305,-304,-300,-286,-271,-264,-271,-285,-293,-294,-287,-275,-266,-255,-237,-231,-238,-243,-243,-234,-229,-229,-239,-247,-255,-256,-246,-229,-202,-181,-174,-169,-159,-150,-145,-135,-128,-123,-115,-108,-101,-101,-93,-91,-90,-90,-87,-81,-73,-61,-49,-85,-93,121,462,738,835,727,508,377,220,147,173,241,350,466,523,493,387,277,248,319,429,518,517,464,403,385,396,387,399,435,504,542,489,371,250,166,145,136,155,187,207,207,213,250,292,269,176,40,-60,-137,-191,-223,-206,-151,-86,-35,13,43,67,85,99,106,107,103,96,88,78,76,67,59,47,37,22,6,-13,-42,-79,-117,-146,-155,-143,-114,-92,-80,-79,-103,-135,-167,-185,-185,-172,-151,-135,-133,-139,-160,-193,-229,-280,-229,41,359,583,555,357,118,-64,-147,-88,-8,48,65,78,74]
arr=np.asarray(l)
dat=arr.reshape(1,-1)#reshape array
prediction=xgb_cl.predict(dat)
if prediction[0]==0:
  print("The person in not having an epileptic seizure currently.")
else:
  print("The person is having an epileptic seizure currently.")
# Out:
# The person is having an epileptic seizure currently.
